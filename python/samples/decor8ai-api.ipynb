# %% [markdown]
# # Decor8AI API Example
# This notebook demonstrates how to call the Decor8AI API using Python.

# %%
# Set environment variables
import os
os.environ("DECOR8AI_API_KEY") = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJhcGlfa2V5X3V1aWQiOiJiYTNhNzA5Yi02MDBmLTRlNzctODJiMy1mNDIwZmFhODVjYjkiLCJpYXQiOjE3MzE2MTkwMzJ9.Jhuo8kAZDtxaYO2S3amrsymF0FRFK2PNDzr_XKmxb7Q"
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/local/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %%
import os
import requests
from decor8ai.client import generate_designs_for_room
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/local/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ### Step 1: Set up mandatory parameters

# %%
# Mandatory Parameters
input_image_url = 'https://prod-files.decor8.ai/test-images/sdk_test_image.png'
mask_info = None
num_images = 2

# Optional Parameters
room_type = 'bedroom'
design_style = 'frenchcountry'
color_scheme = 'COLOR_SCHEME_5'
speciality_decor = 'SPECIALITY_DECOR_5'
keep_original_floor = False
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/local/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ### Step 2: Call the API

# %%
response_json = generate_designs_for_room(
    input_image_url=input_image_url,
    mask_info=mask_info,
    room_type=room_type,
    design_style=design_style,
    num_images=num_images,
    color_scheme=color_scheme,
    speciality_decor=speciality_decor,
    keep_original_floor=keep_original_floor
)
response_json
# Out:
# Running cells with 'Python 3.12.3' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: '/usr/local/bin/python3 -m pip install ipykernel -U --user --force-reinstall'

# %% [markdown]
# ### Step 3: Check for errors in the response

# %%
if response_json['error']:
    print(f"Error: {response_json['error']} - {response_json['message']}")
else:
    # Process the successful response
    images = response_json.get("info", {}).get("images", [])
    
    output_directory = "output-data"
    if not os.path.exists(output_directory):
        os.makedirs(output_directory)

    # Step 4: Save and display images
    for image in images:
        uuid = image.get("uuid")
        image_url = image.get("url")
        
        if uuid and image_url:
            response = requests.get(image_url)
            image_data = response.content
            
            with open(f"{output_directory}/{uuid}.jpg", "wb") as image_file:
                image_file.write(image_data)
            
            print(f"Saved Image: {output_directory}/{uuid}.jpg")

    # Display mask information if available
    mask_info = response_json.get("info", {}).get("mask_info", {})
    print("Mask Info:", mask_info)
